# %%
print ("Adição")

a = float (input ("insira um numero: "))
b = float (input ("insira um numero: "))

soma = a + b

print ("Soma/Adição: ", soma)
# Out:
# Adiçao
# insira um numero4
# insira um numero3
# Soma/Adiçao:  7.0

# %%
print ("Subtração")

a = float (input ("Insira um numero: "))
b = float (input ("Insira um numero: "))

subtração = a - b

print ("Subtração: ", subtração)
# Out:
# Subtração
# Insira um numero:4
# Insira um numero:3
# Subtração 1.0

# %%
print ("Multiplicação")

a = float (input ("Insira um numero: "))
b = float (input ("Insira um numero: "))

multiplicação = a * b

print ("Multiplicação: ", multiplicação)
# Out:
# Multiplicação
# Insira um numero:3
# Insira um numero:4
# Multiplicação 12.0

# %%
print ("Divisão")

a = float (input ("Insira um numero: "))
b = float (input ("Insira um numero: "))

divisão = a / b

print ("Divisão: ", divisão)
# Out:
# Divisão
# Insira um numero:4
# Insira um numero:4
# Divisão 1.0

# %%
print ("Dobro e Triplo")

a = float (input("Insira um numero: "))

print ("Dobro: ", a * 2)
print ("Triplo: ",a * 3)
# Out:
# Dobro e Triplo
# Insira um numero: 2
# Dobro:  4.0
# Triplo:  6.0

# %%
print ("Antecessor e Sucessor")

a = float (input("Insira um numero: "))

print ("Antecessor: ", a - 1)
print ("Sucessor: ", a + 1)
# Out:
# Antecessor e Sucessor
# Insira um numero: 4
# Antecessor:  3.0
# Sucessor:  5.0

# %%
print ("Area do Triangulo")

a = float (input("Insira Altura: "))
b = float (input("Insira Base: "))

print ("Area do triangulo: ", a * b / 2)
# Out:
# Area do triangulo
# Insira Altura: 3
# Insira Base: 3
# Area do triangulo:  4.5
